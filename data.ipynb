# %%
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Out:
# --2024-09-22 00:39:27--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt’
#
# input.txt           100%[===================>]   1.06M   854KB/s    in 1.3s
#
# 2024-09-22 00:39:29 (854 KB/s) - ‘input.txt’ saved [1115394/1115394]

# %%
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
print(text[:1000])
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you know Caius Marcius is chief enemy to the people.
#
# All:
# We know't, we know't.
#
# First Citizen:
# Let us kill him, and we'll have corn at our own price.
# Is't a verdict?
#
# All:
# No more talking on't; let it be done: away, away!
#
# Second Citizen:
# One word, good citizens.
#
# First Citizen:
# We are accounted poor citizens, the patricians good.
# What authority surfeits on would relieve us: if they
# would yield us but the superfluity, while it were
# wholesome, we might guess they relieved us humanely;
# but they think we are too dear: the leanness that
# afflicts us, the object of our misery, is as an
# inventory to particularise their abundance; our
# sufferance is a gain to them Let us revenge this with
# ...

# %%
print(f"Length of characters: {len(text)}")
# Out:
# Length of characters: 1115394

# %%
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size) # Creating the list of unique characters that exist in tech
# Out:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# 65

# %%
# Here we are tokenizing at character level
stoi = {ch:i for i,ch in enumerate(chars)} # string to integer mapping
itos = {i:ch for i,ch in enumerate(chars)} # integer to string mapping
encode = lambda s : [stoi[c] for c in s] # encode a string to a list of integers
decode = lambda l : ''.join([itos[i] for i in l]) # decode a list of integer to a sting

eg = encode("Vishnu Sharma")
print(eg)
print(decode(eg))
# Out:
# [34, 47, 57, 46, 52, 59, 1, 31, 46, 39, 56, 51, 39]
# Vishnu Sharma

# %%
import torch
data = torch.tensor(encode(text), dtype=torch.long)
print(data.shape, data.dtype)
print(data[:1000])
# Out:
# torch.Size([1115394]) torch.int64
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1, 51, 43,  1,
#         57, 54, 43, 39, 49,  8,  0,  0, 13, 50, 50, 10,  0, 31, 54, 43, 39, 49,
#          6,  1, 57, 54, 43, 39, 49,  8,  0,  0, 18, 47, 56, 57, 58,  1, 15, 47,
#         58, 47, 64, 43, 52, 10,  0, 37, 53, 59,  1, 39, 56, 43,  1, 39, 50, 50,
#          1, 56, 43, 57, 53, 50, 60, 43, 42,  1, 56, 39, 58, 46, 43, 56,  1, 58,
#         53,  1, 42, 47, 43,  1, 58, 46, 39, 52,  1, 58, 53,  1, 44, 39, 51, 47,
#         57, 46, 12,  0,  0, 13, 50, 50, 10,  0, 30, 43, 57, 53, 50, 60, 43, 42,
#          8,  1, 56, 43, 57, 53, 50, 60, 43, 42,  8,  0,  0, 18, 47, 56, 57, 58,
#          1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 18, 47, 56, 57, 58,  6,  1, 63,
# ...

# %%
n = int(0.9*len(data))
train_data = data[:n]
valid_data = data[n:]

# %%
block_size = 8
train_data[:block_size+1]
# Out:
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58])

# %%
# Giving the transformor context as little as one to the block size
# model won't exceed the context of the block_size & after that we will start truncating the input

x = train_data[:block_size]
y = train_data[1:block_size+1]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print(f"when input is {context} the target is {target}") 

# time dimension of the tensor that we will be feeding,
# Time dimension refers to the sequential or temporal structure of input data
# Out:
# when input is tensor([18]) the target is 47
# when input is tensor([18, 47]) the target is 56
# when input is tensor([18, 47, 56]) the target is 57
# when input is tensor([18, 47, 56, 57]) the target is 58
# when input is tensor([18, 47, 56, 57, 58]) the target is 1
# when input is tensor([18, 47, 56, 57, 58,  1]) the target is 15
# when input is tensor([18, 47, 56, 57, 58,  1, 15]) the target is 47
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47]) the target is 58

# %%
# Batch dimension 
torch.manual_seed(1337)
batch_size = 4 # number of independent sequences that will be processed in parallel
block_size = 8 # context length

def get_batch(split):
    data = train_data if split=='train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    return x, y

xb, yb = get_batch('train')
print('inputs')
print(xb.shape)
print(xb)
print('targets')
print(yb.shape)
print(yb)

print('------------------------')

for b in range(batch_size): # batch dimension
    for t in range(block_size): # time dimension
        context = xb[b, :t+1]
        target = yb[b, t]
        print(f"when input is {context.tolist()} the target: {target}")
# Out:
# inputs
# torch.Size([4, 8])
# tensor([[24, 43, 58,  5, 57,  1, 46, 43],
#         [44, 53, 56,  1, 58, 46, 39, 58],
#         [52, 58,  1, 58, 46, 39, 58,  1],
#         [25, 17, 27, 10,  0, 21,  1, 54]])
# targets
# torch.Size([4, 8])
# tensor([[43, 58,  5, 57,  1, 46, 43, 39],
#         [53, 56,  1, 58, 46, 39, 58,  1],
#         [58,  1, 58, 46, 39, 58,  1, 46],
#         [17, 27, 10,  0, 21,  1, 54, 39]])
# ------------------------
# when input is [24] the target: 43
# when input is [24, 43] the target: 58
# when input is [24, 43, 58] the target: 5
# when input is [24, 43, 58, 5] the target: 57
# when input is [24, 43, 58, 5, 57] the target: 1
# when input is [24, 43, 58, 5, 57, 1] the target: 46
# when input is [24, 43, 58, 5, 57, 1, 46] the target: 43
# when input is [24, 43, 58, 5, 57, 1, 46, 43] the target: 39
# when input is [44] the target: 53
# when input is [44, 53] the target: 56
# when input is [44, 53, 56] the target: 1
# when input is [44, 53, 56, 1] the target: 58
# ...

# %% [raw]
# Let's break down the line:
# ix = torch.randint(len(data) - block_size, (batch_size,))
#
# What this line does:
# torch.randint generates random integers between a specified range.
# The range is from 0 to len(data) - block_size, ensuring that the selected indices can safely be used to extract a sequence of block_size tokens from data without exceeding the data length.
# (batch_size,) specifies that we want batch_size random integers. This results in a 1D tensor of size batch_size.
# Example:
# Let’s assume:
#
# data is a sequence of length 100.
# block_size = 8 (this means we want to extract sequences of length 8).
# batch_size = 4 (we want 4 such sequences in each batch).
# Now, len(data) - block_size becomes 100 - 8 = 92. This means we are selecting random starting indices between 0 and 91.
#
# Example Output:
# ix = torch.randint(92, (4,))
# print(ix)  # This might output something like:
# tensor([23, 67, 12, 89])
# What this means:
# Random indices [23, 67, 12, 89] have been selected from the data.
#
# These will be the starting points for extracting 4 independent sequences, each of length 8, from the data array.
# The first sequence starts at index 23, the second at 67, and so on.
# This allows the batch to contain independent subsequences of block_size tokens from random positions in the dataset.

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
torch.manual_seed(1337)

class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)

    def forward(self, idx, targets=None):

        logits = self.token_embedding_table(idx) # (This will be in the dimension of Batch x Time x Channels)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C) 
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens): # idx is (B,T) array of indices in the current context
        for _ in range(max_new_tokens):
            logits, loss = self(idx) # getting the predictions
            logits = logits[:, -1, :] # plucking out the last step result
            probs = F.softmax(logits, dim=-1) # getting the probabilities
            idx_next = torch.multinomial(probs, num_samples=1) # sample from distribution
            idx = torch.cat((idx, idx_next), dim=1) # append sampled index to running sequence
        return idx
            

m = BigramLanguageModel(vocab_size)
logits, loss = m(xb, yb)


print(decode(m.generate(idx=torch.zeros((1,1), dtype=torch.long), max_new_tokens=100)[0].tolist()))
# Out:
# Sr?qP-QWktXoL&jLDJgOLVz'RIoDqHdhsV&vLLxatjscMpwLERSPyao.qfzs$Ys$zF-w,;eEkzxjgCKFChs!iWW.ObzDnxA Ms$3

# %% [raw]
# ## For Generate function
# In your generate method, the probabilities are derived from the logits (predictions) that the model produces, and the sampling step is used to pick the next token to generate. Here's a breakdown of the key parts:
#
# Logits: The model output (logits) represents the raw, unnormalized predictions for the next token for each position in the sequence. These logits are of size (B, vocab_size) where B is the batch size and vocab_size is the number of possible tokens in your vocabulary.
#
# Softmax (Probabilities):
#
# python
# Copy code
# probs = F.softmax(logits, dim=-1)
# This step converts the logits into probabilities using the softmax function. Softmax transforms the logits into a probability distribution over the vocabulary by scaling the logits so that they sum up to 1. Each value in the resulting probs tensor represents the probability of selecting a particular token from the vocabulary at the next step.
#
# Sampling:
#
# python
# Copy code
# idx_next = torch.multinomial(probs, num_samples=1)
# Here, torch.multinomial samples from the probability distribution probs. It takes one sample (num_samples=1) based on the given probabilities, meaning that it probabilistically chooses the next token according to the likelihoods provided by probs. Tokens with higher probabilities are more likely to be selected, but it's not deterministic—there's a randomness component.
#
# Appending to Sequence:
#
# python
# Copy code
# idx = torch.cat((idx, idx_next), dim=1)
# The newly sampled token (idx_next) is appended to the running sequence idx, making it the latest token in the sequence. This process repeats for max_new_tokens iterations, generating a sequence of new tokens based on the model's predictions at each step.

# %%
optimizer = torch.optim.AdamW(m.parameters(), lr=1e-3)

# %%
batch_size = 32
for steps in range(10000):
    xb, yb = get_batch('train')

    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

    print(loss.item())
# Out:
# 3.0028276443481445
# 3.146709680557251
# 3.1486430168151855
# 3.0929300785064697
# 3.0615363121032715
# 3.0417559146881104
# 3.063460111618042
# 3.009525775909424
# 3.1345720291137695
# 3.0597612857818604
# 3.011056900024414
# 3.080782890319824
# 3.0832319259643555
# 2.99129319190979
# 3.09507417678833
# 3.093895673751831
# 3.0154566764831543
# 3.078781843185425
# 3.050755023956299
# 3.0521421432495117
# 3.0700321197509766
# 3.046471357345581
# 3.036100149154663
# 3.100830554962158
# 3.050074338912964
# 3.081789016723633
# 3.0270721912384033
# 3.080142021179199
# 2.97471022605896
# 3.0658929347991943
# 3.025282859802246
# 3.0089457035064697
# 2.958301067352295
# 3.0811023712158203
# 3.1233348846435547
# 3.0981369018554688
# 3.0425126552581787
# 3.0476481914520264
# 3.1276116371154785
# 3.1049578189849854
# 3.1365420818328857
# 3.081303596496582
# 3.0375571250915527
# 3.0360519886016846
# 3.116507053375244
# 3.093311309814453
# 2.929199457168579
# 2.9194142818450928
# ...

# %%
print(decode(m.generate(idx=torch.zeros((1,1), dtype=torch.long), max_new_tokens=500)[0].tolist()))
# Out:
# Tailapo belll w anive? nanowalarpe JOFiase ig bo, t ced bere
# LLe neset aiemy
# I wie yat y mexirourous ceckierelsaru t IAREEroutersay.
# AD:
# Se m ane! :
# Hobsad, s IAle h mexK:
# We, makisoung, hall-hithin p wate st--
# TE:
# Ifur met th hire onsteiahe cour, RDilothay Mube t VOLUKERUS:
#
# ABEXExe s s hpr ug y'd it trr,
# I lay:
# EOMy athaveanghur amex.
# Whes:
# F: I
#
# Buru.
# Serth'Whth:
# AUESI isin. thed thmyo as ELI g.
# CHUSisthethellend:
# GAnd fo,
# CKI:
# DULird m wotiotoup-PAny, har lre uf,
# HEL:
# FLod bery s. angupr,

# %% [markdown]
# ## Attention Mechanism

# %%
torch.manual_seed(1337)

B,T,C = 4, 8, 2
x = torch.randn(B,T,C)
x.shape
# Out:
# torch.Size([4, 8, 2])

# %% [markdown]
# ### version 1

# %%
# We want x [b, t] = mean_{i<=t} x [b, i]

xbow = torch.zeros((B,T,C))
for b in range(B):
    for t in range(T):
        xprev = x[b, :t+1] # (t,C)
        xbow[b,t] = torch.mean(xprev, 0)

x[0]
# Out:
# tensor([[ 0.1808, -0.0700],
#         [-0.3596, -0.9152],
#         [ 0.6258,  0.0255],
#         [ 0.9545,  0.0643],
#         [ 0.3612,  1.1679],
#         [-1.3499, -0.5102],
#         [ 0.2360, -0.2398],
#         [-0.9211,  1.5433]])

# %%
xbow[0]
# Out:
# tensor([[ 0.1808, -0.0700],
#         [-0.0894, -0.4926],
#         [ 0.1490, -0.3199],
#         [ 0.3504, -0.2238],
#         [ 0.3525,  0.0545],
#         [ 0.0688, -0.0396],
#         [ 0.0927, -0.0682],
#         [-0.0341,  0.1332]])

# %% [markdown]
# ### Version 2

# %%
wei = torch.tril(torch.ones(T,T)) # the creation of lower trinagle yields the result so that current tokens communicate with previous tokens only
wei = wei / wei.sum(1, keepdim=True)
xbow2 = wei @ x # (B,T,T) @ (B,T,C) ----------> (B,T,C)
torch.allclose(xbow, xbow2)
# Out:
# False

# %%
xbow2[0]
# Out:
# tensor([[ 0.1808, -0.0700],
#         [-0.0894, -0.4926],
#         [ 0.1490, -0.3199],
#         [ 0.3504, -0.2238],
#         [ 0.3525,  0.0545],
#         [ 0.0688, -0.0396],
#         [ 0.0927, -0.0682],
#         [-0.0341,  0.1332]])

# %% [markdown]
# ### Version 3

# %% [raw]
# Implementing self attention on a single head!

# %%
torch.manual_seed(1337)
B,T,C = 4, 8, 32
x = torch.randn(B,T,C)

head_size = 16
key = nn.Linear(C, head_size, bias=False)
query = nn.Linear(C, head_size, bias=False)
value = nn.Linear(C, head_size, bias=False)
k = key(x)
q = query(x)
wei = q @ k.transpose(-2,-1) # (B, T, 16) @ (B, 16, T) -----> (B,T,T)

tril = torch.tril(torch.ones(T,T))
# wei = torch.zeros((T,T))
wei = wei.masked_fill(tril==0, float('-inf'))
wei = F.softmax(wei, dim=-1)

v = value(x)
out = wei @ v
# out = wei @ x

out.shape
# Out:
# torch.Size([4, 8, 32])

# %%
wei[0]
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.1574, 0.8426, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2088, 0.1646, 0.6266, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5792, 0.1187, 0.1889, 0.1131, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0294, 0.1052, 0.0469, 0.0276, 0.7909, 0.0000, 0.0000, 0.0000],
#         [0.0176, 0.2689, 0.0215, 0.0089, 0.6812, 0.0019, 0.0000, 0.0000],
#         [0.1691, 0.4066, 0.0438, 0.0416, 0.1048, 0.2012, 0.0329, 0.0000],
#         [0.0210, 0.0843, 0.0555, 0.2297, 0.0573, 0.0709, 0.2423, 0.2391]],
#        grad_fn=<SelectBackward0>)

# %%
k = torch.randn(B, T, head_size)
q = torch.randn(B, T, head_size)
wei = q @ k.transpose(-2, -1) * head_size**-0.5 # This divison by square root of head_size with normalize the wei variance 
# The above transformation is necessary otherwise upon applying softmax in this wei will yield context from the token with max weight only for all
# cases which is undesired.
